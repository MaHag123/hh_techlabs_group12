# %%
#1. Get a dataset of all Zählstellen
import json
import pandas as pd
import requests
import numpy as np

# %%
#read the data from the web
response = requests.get("https://iot.hamburg.de/v1.1/Datastreams?$filter=properties/serviceName eq 'HH_STA_AutomatisierteVerkehrsmengenerfassung' and properties/layerName eq 'Anzahl_Kfz_Zaehlstelle_1-Tag'&$top=500")

# %%
#Turn the JSON response in usable data
#Extract the data from the the response object
betterdata=response.json()
#only select the data, which are under the heading "value" and convert this to a pandas dataframe
test = betterdata["value"]
df = pd.DataFrame.from_dict(test)
df.head()
# Out:
#                                          description  @iot.id  \
# 0  Die Anzahl der von der Infrarotkamera erfasste...    15808
# 1  Die Anzahl der von der Infrarotkamera erfasste...    14812
# 2  Die Anzahl der von der Infrarotkamera erfasste...    13008
# 3  Die Anzahl der von der Infrarotkamera erfasste...    13616
# 4  Die Anzahl der von der Infrarotkamera erfasste...    13600
#
#                                                 name  \
# 0  Kfz-Aufkommen an Verkehrszählstelle 0216931 im...
# 1  Kfz-Aufkommen an Verkehrszählstelle 0222972 im...
# 2  Kfz-Aufkommen an Verkehrszählstelle 0244920 im...
# 3  Kfz-Aufkommen an Verkehrszählstelle 0311971 im...
# 4  Kfz-Aufkommen an Verkehrszählstelle 0314962 im...
#
#                                      observationType  \
# 0  http://defs.opengis.net/elda-common/ogc-def/re...
# 1  http://defs.opengis.net/elda-common/ogc-def/re...
# 2  http://defs.opengis.net/elda-common/ogc-def/re...
# 3  http://defs.opengis.net/elda-common/ogc-def/re...
# 4  http://defs.opengis.net/elda-common/ogc-def/re...
#
#                                         observedArea  \
# 0  {'type': 'Point', 'coordinates': [9.949614, 53...
# 1  {'type': 'Point', 'coordinates': [10.140319, 5...
# 2  {'type': 'Point', 'coordinates': [10.107262, 5...
# 3  {'type': 'Point', 'coordinates': [10.034157, 5...
# 4  {'type': 'Point', 'coordinates': [10.057635, 5...
#
#                                       phenomenonTime  \
# 0  2021-08-10T22:00:00.000Z/2021-08-13T21:59:59.000Z
# 1  2020-10-31T23:00:00.000Z/2021-08-13T21:59:59.000Z
# 2  2020-10-31T23:00:00.000Z/2021-08-13T21:59:59.000Z
# 3  2020-12-06T23:00:00.000Z/2021-08-13T21:59:59.000Z
# 4  2020-10-31T23:00:00.000Z/2021-08-13T21:59:59.000Z
#
#                                           properties  \
# 0  {'metadata': 'https://registry.gdi-de.org/id/d...
# 1  {'metadata': 'https://registry.gdi-de.org/id/d...
# 2  {'metadata': 'https://registry.gdi-de.org/id/d...
# 3  {'metadata': 'https://registry.gdi-de.org/id/d...
# 4  {'metadata': 'https://registry.gdi-de.org/id/d...
#
#                                           resultTime  \
# 0  2021-08-12T01:47:21.810Z/2021-08-14T01:47:51.680Z
# 1  2021-01-23T01:47:30.603Z/2021-08-14T01:45:11.445Z
# 2  2021-02-02T15:01:35.924Z/2021-08-14T01:17:05.064Z
# 3  2021-02-02T13:21:36.627Z/2021-08-14T01:25:49.916Z
# 4  2021-01-23T01:27:30.375Z/2021-08-14T01:25:24.508Z
#
#                                     @iot.selfLink  \
# 0  https://iot.hamburg.de/v1.1/Datastreams(15808)
# 1  https://iot.hamburg.de/v1.1/Datastreams(14812)
# 2  https://iot.hamburg.de/v1.1/Datastreams(13008)
# 3  https://iot.hamburg.de/v1.1/Datastreams(13616)
# 4  https://iot.hamburg.de/v1.1/Datastreams(13600)
#
#                                    unitOfMeasurement  \
# 0  {'name': 'Anzahl', 'symbol': None, 'definition...
# 1  {'name': 'Anzahl', 'symbol': None, 'definition...
# 2  {'name': 'Anzahl', 'symbol': None, 'definition...
# 3  {'name': 'Anzahl', 'symbol': None, 'definition...
# 4  {'name': 'Anzahl', 'symbol': None, 'definition...
#
#                             Thing@iot.navigationLink  \
# 0  https://iot.hamburg.de/v1.1/Datastreams(15808)...
# 1  https://iot.hamburg.de/v1.1/Datastreams(14812)...
# 2  https://iot.hamburg.de/v1.1/Datastreams(13008)...
# 3  https://iot.hamburg.de/v1.1/Datastreams(13616)...
# 4  https://iot.hamburg.de/v1.1/Datastreams(13600)...
#
#                      Observations@iot.navigationLink  \
# 0  https://iot.hamburg.de/v1.1/Datastreams(15808)...
# 1  https://iot.hamburg.de/v1.1/Datastreams(14812)...
# 2  https://iot.hamburg.de/v1.1/Datastreams(13008)...
# 3  https://iot.hamburg.de/v1.1/Datastreams(13616)...
# 4  https://iot.hamburg.de/v1.1/Datastreams(13600)...
#
#                  ObservedProperty@iot.navigationLink  \
# 0  https://iot.hamburg.de/v1.1/Datastreams(15808)...
# 1  https://iot.hamburg.de/v1.1/Datastreams(14812)...
# 2  https://iot.hamburg.de/v1.1/Datastreams(13008)...
# 3  https://iot.hamburg.de/v1.1/Datastreams(13616)...
# 4  https://iot.hamburg.de/v1.1/Datastreams(13600)...
#
#                            Sensor@iot.navigationLink
# 0  https://iot.hamburg.de/v1.1/Datastreams(15808)...
# 1  https://iot.hamburg.de/v1.1/Datastreams(14812)...
# 2  https://iot.hamburg.de/v1.1/Datastreams(13008)...
# 3  https://iot.hamburg.de/v1.1/Datastreams(13616)...
# 4  https://iot.hamburg.de/v1.1/Datastreams(13600)...

# %%
#2. Loop through the links of all "Zählstellen" to receive a dataset of the nr. of vehicles for every day/every "Zählstelle"

## generate links and append to df
df["links"] = df["Observations@iot.navigationLink"].apply(lambda x: x + "?$top=600")
df['id'] = df['@iot.id']

# clean dataframe where we dont find geo information
# 2 rows should be removed
print(f'Rows before NA removal: {len(df)}')
df = df.dropna()
print(f'Rows after NA removal: {len(df)}')
# extract the lat/long information to join later
df['long'] = df['observedArea'].apply(lambda x: x['coordinates'][0])
df['lat'] = df['observedArea'].apply(lambda x: x['coordinates'][1])
# Out:
# Rows before NA removal: 500
# Rows after NA removal: 494

# %%
# create a list for the results
columns = ['@iot.id','phenomenonTime', 'result','resultTime']
missing_data = list()
df_complete = pd.DataFrame(columns = columns)

unique_links = df["links"].unique()

for link in unique_links:
    print(f'Retrieving data for {link}')
    response = requests.get(link)
    json = response.json()
    df_temp = pd.DataFrame.from_dict(json["value"])
    if set(columns).issubset(set(df_temp.columns)):
        df_temp = df_temp[columns]
        df_temp['id'] = link[40:45]
        df_complete = df_complete.append(df_temp,sort=False)
#        df_complete['id'] = df_complete['id'].astype('int64')
    else:
        # no data available
        print(f'---- WARNING: No data available or wrong columns selected for {link}')
        missing_data.append(link)
df_complete['id'] = df_complete['id'].astype('int64')
df_complete['result'] = df_complete['result'].astype('int64')
# Out:
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15808)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14812)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13008)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13616)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13600)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13596)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13636)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15732)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13400)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15812)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15736)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14568)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15764)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13840)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13204)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15756)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15780)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15824)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15828)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13292)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15792)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15796)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15772)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15836)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13136)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15804)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14744)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15844)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15848)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15788)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15776)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15864)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13316)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15852)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15888)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15876)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13892)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13324)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15784)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15856)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15892)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14708)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15800)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15860)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13792)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15868)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13984)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15880)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13380)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15872)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15816)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13996)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15820)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15884)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13972)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13724)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13404)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13084)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15832)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13044)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15740)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13120)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13916)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14732)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15760)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(15768)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13164)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14592)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14576)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13180)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14144)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14184)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14104)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14180)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14164)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13924)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14000)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13200)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13932)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12992)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13432)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13824)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13288)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13784)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14108)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13912)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13124)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13168)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13712)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14288)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13744)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13480)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13476)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13276)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13132)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13944)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13052)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13032)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13256)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13232)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13240)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13268)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13040)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13264)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14188)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14196)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13472)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13940)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13788)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13528)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14392)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13228)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13860)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14056)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14060)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13532)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14268)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13348)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13780)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13520)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14176)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13320)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13540)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14428)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14436)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14464)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12988)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14236)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14008)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14300)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13716)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13252)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13388)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14240)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13608)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13848)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14388)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13868)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13900)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14216)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14212)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13888)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14356)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14028)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14360)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14424)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13920)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14364)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14128)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13428)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14452)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14460)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14468)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13612)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14476)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13936)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14036)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13980)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14040)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14524)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13028)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14544)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13632)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14224)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14584)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13644)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14588)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14120)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13648)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14628)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13992)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13656)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14644)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14632)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14648)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13676)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14724)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14780)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13688)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14004)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14804)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14864)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13700)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14800)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14832)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14824)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14840)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14828)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13748)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14904)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13776)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14740)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14728)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14736)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14748)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14756)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14760)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13072)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14768)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14788)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14792)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14228)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14540)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13808)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13804)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14276)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13448)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13852)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12996)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13000)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13584)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13592)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14352)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13576)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13964)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13568)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13968)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13564)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13560)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14292)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12940)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12968)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12944)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13080)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12936)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13148)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13580)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12956)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13588)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14204)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13872)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14100)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14304)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14328)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14248)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14836)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13796)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14016)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14320)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14012)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13424)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13420)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14324)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14232)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14308)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14296)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13544)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14244)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14480)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13212)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13208)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14316)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14312)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13216)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13224)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14020)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14024)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14492)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14488)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14484)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14820)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14816)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14808)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14500)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14536)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14776)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13704)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14472)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13696)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14844)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13680)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14444)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14796)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14440)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14448)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13820)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13828)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13812)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13020)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13816)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13012)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13832)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13836)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14048)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14044)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13768)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13764)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14764)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13760)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13284)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13548)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13280)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13068)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13064)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13076)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13188)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13128)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13192)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13184)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14720)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13732)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13740)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14772)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14136)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13160)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13960)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13720)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13176)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13172)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13708)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13728)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14096)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13956)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13948)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13952)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12916)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12912)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14116)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13092)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14112)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13556)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14192)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13144)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13140)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14172)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13088)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14456)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14168)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14200)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13100)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13096)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14160)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13552)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13108)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13104)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13116)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13112)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13640)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13756)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13036)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13620)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13524)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13752)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14580)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13536)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13436)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14220)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13260)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13244)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14512)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14516)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14208)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14520)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13660)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14852)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13272)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14508)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14528)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13048)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13500)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13496)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13440)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13464)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13468)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14532)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13684)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13236)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13456)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13856)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14752)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13460)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13372)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13444)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13396)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13392)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14052)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13652)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14552)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14600)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13384)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13308)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13368)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13332)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13376)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14556)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13304)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13772)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14032)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14572)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13340)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14068)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14080)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14064)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14084)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14560)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14076)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14072)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14860)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13416)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13412)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13408)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13452)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13908)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12904)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14564)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12908)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13976)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14340)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14264)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14260)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13220)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14596)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13672)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13668)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14784)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13060)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14284)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13056)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14280)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14604)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13572)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14608)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13628)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14620)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12972)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12980)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12984)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14636)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12976)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13800)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14652)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14408)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14432)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14404)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14660)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14272)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14140)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14704)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13736)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14624)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14124)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14616)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14668)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14132)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13156)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14696)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13152)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14676)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14672)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14380)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14384)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14148)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14376)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14680)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14684)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12932)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13988)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14688)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12928)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14700)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14092)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14088)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14692)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14156)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14152)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13492)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13488)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13928)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14716)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13484)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12952)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12948)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13300)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13604)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13296)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14348)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14252)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14848)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14548)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13516)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13512)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14856)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13508)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13248)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12964)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14256)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14504)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13864)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12924)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12920)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13004)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(12960)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13904)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(14412)/Observations?$top=600

# %%
missing_data
# Out:
# []

# %%
len(df_complete)
# Out:
# 121652

# %%
df_complete.head()
# Out:
#      @iot.id                                     phenomenonTime  result  \
# 0  217458399  2021-08-11T22:00:00.000Z/2021-08-12T21:59:59.000Z    1090
# 1  216650904  2021-08-10T22:00:00.000Z/2021-08-11T21:59:59.000Z    1040
# 2  219332283  2021-08-12T22:00:00.000Z/2021-08-13T21:59:59.000Z    1013
# 0   51222146  2021-01-21T23:00:00.000Z/2021-01-22T22:59:59.000Z    7831
# 1   51496408  2021-01-22T23:00:00.000Z/2021-01-23T22:59:59.000Z    5187
#
#                  resultTime     id
# 0  2021-08-13T01:47:21.106Z  15808
# 1  2021-08-12T01:47:21.810Z  15808
# 2  2021-08-14T01:47:51.680Z  15808
# 0  2021-01-23T01:47:30.603Z  14812
# 1  2021-01-24T01:50:38.217Z  14812

# %%
df_raw = pd.merge(df_complete,df[['id','lat','long']], how='inner',on='id')

# %%
df_raw.head()
# Out:
#      @iot.id                                     phenomenonTime  result  \
# 0  217458399  2021-08-11T22:00:00.000Z/2021-08-12T21:59:59.000Z    1090
# 1  216650904  2021-08-10T22:00:00.000Z/2021-08-11T21:59:59.000Z    1040
# 2  219332283  2021-08-12T22:00:00.000Z/2021-08-13T21:59:59.000Z    1013
# 3   51222146  2021-01-21T23:00:00.000Z/2021-01-22T22:59:59.000Z    7831
# 4   51496408  2021-01-22T23:00:00.000Z/2021-01-23T22:59:59.000Z    5187
#
#                  resultTime     id        lat       long
# 0  2021-08-13T01:47:21.106Z  15808  53.650597   9.949614
# 1  2021-08-12T01:47:21.810Z  15808  53.650597   9.949614
# 2  2021-08-14T01:47:51.680Z  15808  53.650597   9.949614
# 3  2021-01-23T01:47:30.603Z  14812  53.628402  10.140319
# 4  2021-01-24T01:50:38.217Z  14812  53.628402  10.140319

# %%
df_raw.loc[df_raw['id']!=13600]
# Out:
#           @iot.id                                     phenomenonTime  result  \
# 0       217458399  2021-08-11T22:00:00.000Z/2021-08-12T21:59:59.000Z    1090
# 1       216650904  2021-08-10T22:00:00.000Z/2021-08-11T21:59:59.000Z    1040
# 2       219332283  2021-08-12T22:00:00.000Z/2021-08-13T21:59:59.000Z    1013
# 3        51222146  2021-01-21T23:00:00.000Z/2021-01-22T22:59:59.000Z    7831
# 4        51496408  2021-01-22T23:00:00.000Z/2021-01-23T22:59:59.000Z    5187
# ...           ...                                                ...     ...
# 121647  207523877  2021-07-30T22:00:00.000Z/2021-07-31T21:59:59.000Z    4156
# 121648  208617775  2021-07-31T22:00:00.000Z/2021-08-01T21:59:59.000Z    2851
# 121649  210239080  2021-08-01T22:00:00.000Z/2021-08-02T21:59:59.000Z    4901
# 121650  211949905  2021-08-02T22:00:00.000Z/2021-08-03T21:59:59.000Z    4572
# 121651  213887390  2021-08-03T22:00:00.000Z/2021-08-04T21:59:59.000Z    5272
#
#                       resultTime     id        lat       long
# 0       2021-08-13T01:47:21.106Z  15808  53.650597   9.949614
# 1       2021-08-12T01:47:21.810Z  15808  53.650597   9.949614
# 2       2021-08-14T01:47:51.680Z  15808  53.650597   9.949614
# 3       2021-01-23T01:47:30.603Z  14812  53.628402  10.140319
# 4       2021-01-24T01:50:38.217Z  14812  53.628402  10.140319
# ...                          ...    ...        ...        ...
# 121647  2021-08-01T01:36:41.721Z  14412  53.530336  10.065717
# 121648  2021-08-02T01:36:38.529Z  14412  53.530336  10.065717
# 121649  2021-08-03T01:37:01.595Z  14412  53.530336  10.065717
# 121650  2021-08-04T01:38:46.295Z  14412  53.530336  10.065717
# 121651  2021-08-05T01:37:38.011Z  14412  53.530336  10.065717
#
# [121521 rows x 7 columns]

# %% [markdown]
# ## Debug section

# %%
# only for debugging
columns_test = ['@iot.id','phenomenonTime', 'result','resultTime']
missing_data_test = list()
df_complete_test = pd.DataFrame(columns = columns_test)

# first link doesnt return data, second one works
unique_links_test = ['https://iot.hamburg.de/v1.1/Datastreams(13196)/Observations?$top=600',
                     'https://iot.hamburg.de/v1.1/Datastreams(13596)/Observations?$top=600']

for link in unique_links_test:
    print(f'Retrieving data for {link}')
    response = requests.get(link)
    json = response.json()
    df_temp_test = pd.DataFrame.from_dict(json["value"])
    if set(columns_test).issubset(set(df_temp_test.columns)):
        df_temp_test = df_temp_test[columns_test]
        df_temp_test['id'] = link[40:45]
        df_complete_test = df_complete_test.append(df_temp_test,sort=False)
        df_complete_test['id'] = df_temp_test['id'].astype('int64')
    else:
        # no data available
        print(f'---- WARNING: No data available or wrong columns selected for {link}')
        missing_data_test.append(link)
# Out:
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13196)/Observations?$top=600
# ---- WARNING: No data available or wrong columns selected for https://iot.hamburg.de/v1.1/Datastreams(13196)/Observations?$top=600
# Retrieving data for https://iot.hamburg.de/v1.1/Datastreams(13596)/Observations?$top=600

# %%
df_raw_test = pd.merge(df_complete_test,df[['id','lat','long']], how='inner',on='id')

# %%
df_raw_test
# Out:
#        @iot.id                                     phenomenonTime   result  \
# 0     51218837  2021-01-21T23:00:00.000Z/2021-01-22T22:59:59.000Z  11444.0
# 1     51493103  2021-01-22T23:00:00.000Z/2021-01-23T22:59:59.000Z   9611.0
# 2     51730741  2021-01-23T23:00:00.000Z/2021-01-24T22:59:59.000Z   6940.0
# 3     51836604  2020-10-31T23:00:00.000Z/2020-11-01T22:59:59.000Z  11225.0
# 4     51836487  2020-11-30T23:00:00.000Z/2020-12-01T22:59:59.000Z  18010.0
# ..         ...                                                ...      ...
# 126  152467732  2021-06-17T22:00:00.000Z/2021-06-18T21:59:59.000Z  13858.0
# 127  154042210  2021-06-18T22:00:00.000Z/2021-06-19T21:59:59.000Z  10788.0
# 128  155510409  2021-06-19T22:00:00.000Z/2021-06-20T21:59:59.000Z    466.0
# 129  160875346  2021-06-24T22:00:00.000Z/2021-06-25T21:59:59.000Z   1828.0
# 130  161093015  2021-06-25T22:00:00.000Z/2021-06-26T21:59:59.000Z   9068.0
#
#                    resultTime     id        lat       long
# 0    2021-03-15T20:26:03.599Z  13596  53.579579  10.057484
# 1    2021-03-15T20:47:20.954Z  13596  53.579579  10.057484
# 2    2021-03-15T21:07:40.572Z  13596  53.579579  10.057484
# 3    2021-03-15T13:09:26.108Z  13596  53.579579  10.057484
# 4    2021-03-15T13:09:53.581Z  13596  53.579579  10.057484
# ..                        ...    ...        ...        ...
# 126  2021-06-19T01:24:36.318Z  13596  53.579579  10.057484
# 127  2021-06-20T01:24:37.147Z  13596  53.579579  10.057484
# 128  2021-06-21T01:24:28.328Z  13596  53.579579  10.057484
# 129  2021-06-26T01:24:42.911Z  13596  53.579579  10.057484
# 130  2021-06-27T01:24:35.686Z  13596  53.579579  10.057484
#
# [131 rows x 7 columns]

# %% [markdown]
# Visualisierung - Patricia
# 1. Wochentage rausfinden und Durchschnitt über Wochentage legen

# %%
weekday_list=[]

for i in df_raw['phenomenonTime']:
    t = i[25:35]
    day = pd.Timestamp(t)
    weekday = day.day_name()
    print(weekday)

weekday_list.append(weekday)
# Out:
# Thursday
# Wednesday
# Friday
# Friday
# Saturday
# Sunday
# Friday
# Tuesday
# Monday
# Saturday
# Tuesday
# Thursday
# Sunday
# Saturday
# Monday
# Friday
# Wednesday
# Tuesday
# Thursday
# Monday
# Tuesday
# Saturday
# Sunday
# Monday
# Tuesday
# Sunday
# Wednesday
# Friday
# Friday
# Wednesday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Thursday
# Saturday
# Sunday
# Wednesday
# Monday
# Thursday
# Friday
# Tuesday
# Saturday
# Sunday
# Wednesday
# Saturday
# Sunday
# Monday
# Thursday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Monday
# Friday
# Thursday
# Saturday
# Tuesday
# Friday
# Sunday
# Wednesday
# Wednesday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Monday
# Friday
# Tuesday
# Thursday
# Wednesday
# Friday
# Saturday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Sunday
# Thursday
# Wednesday
# Thursday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Friday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Saturday
# Friday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Sunday
# Friday
# Tuesday
# Monday
# Wednesday
# Wednesday
# Sunday
# Friday
# Monday
# Wednesday
# Tuesday
# Saturday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Sunday
# Tuesday
# Saturday
# Saturday
# Monday
# Sunday
# Tuesday
# Friday
# Monday
# Saturday
# Monday
# Friday
# Monday
# Thursday
# Wednesday
# Sunday
# Sunday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Sunday
# Friday
# Monday
# Thursday
# Saturday
# Thursday
# Sunday
# Friday
# Saturday
# Thursday
# Thursday
# Saturday
# Friday
# Sunday
# Friday
# Tuesday
# Monday
# Wednesday
# Wednesday
# Thursday
# Friday
# Saturday
# Monday
# Tuesday
# Thursday
# Saturday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Monday
# Tuesday
# Friday
# Saturday
# Sunday
# Monday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Thursday
# Thursday
# Thursday
# Wednesday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Tuesday
# Friday
# Saturday
# Thursday
# Friday
# Monday
# Wednesday
# Wednesday
# Tuesday
# Sunday
# Friday
# Saturday
# Monday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Wednesday
# Friday
# Saturday
# Monday
# Thursday
# Sunday
# Saturday
# Thursday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Monday
# Sunday
# Wednesday
# Friday
# Sunday
# Thursday
# Sunday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Sunday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Thursday
# Saturday
# Sunday
# Wednesday
# Saturday
# Friday
# Monday
# Wednesday
# Tuesday
# Saturday
# Thursday
# Sunday
# Friday
# Saturday
# Wednesday
# Wednesday
# Thursday
# Friday
# Tuesday
# Wednesday
# Tuesday
# Sunday
# Friday
# Monday
# Saturday
# Sunday
# Wednesday
# Monday
# Thursday
# Tuesday
# Friday
# Tuesday
# Monday
# Friday
# Tuesday
# Wednesday
# Thursday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Monday
# Tuesday
# Sunday
# Monday
# Saturday
# Thursday
# Friday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Friday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Thursday
# Monday
# Tuesday
# Wednesday
# Monday
# Friday
# Saturday
# Sunday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Tuesday
# Sunday
# Tuesday
# Saturday
# Monday
# Wednesday
# Thursday
# Sunday
# Tuesday
# Monday
# Wednesday
# Friday
# Thursday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Friday
# Friday
# Sunday
# Wednesday
# Saturday
# Thursday
# Monday
# Sunday
# Monday
# Friday
# Tuesday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Wednesday
# Sunday
# Friday
# Thursday
# Sunday
# Saturday
# Tuesday
# Friday
# Wednesday
# Saturday
# Tuesday
# Monday
# Sunday
# Thursday
# Friday
# Monday
# Tuesday
# Wednesday
# Saturday
# Thursday
# Sunday
# Wednesday
# Friday
# Monday
# Thursday
# Saturday
# Tuesday
# Friday
# Wednesday
# Sunday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Thursday
# Wednesday
# Friday
# Saturday
# Thursday
# Friday
# Sunday
# Saturday
# Monday
# Sunday
# Tuesday
# Monday
# Saturday
# Wednesday
# Thursday
# Thursday
# Tuesday
# Wednesday
# Friday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Saturday
# Friday
# Saturday
# Sunday
# Sunday
# Tuesday
# Saturday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Sunday
# Friday
# Monday
# Tuesday
# Saturday
# Thursday
# Monday
# Wednesday
# Thursday
# Sunday
# Friday
# Wednesday
# Saturday
# Monday
# Sunday
# Thursday
# Monday
# Tuesday
# Wednesday
# Saturday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Sunday
# Friday
# Monday
# Thursday
# Friday
# Wednesday
# Sunday
# Thursday
# Tuesday
# Friday
# Wednesday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Friday
# Thursday
# Saturday
# Tuesday
# Friday
# Wednesday
# Sunday
# Saturday
# Thursday
# Monday
# Sunday
# Monday
# Friday
# Thursday
# Tuesday
# Saturday
# Tuesday
# Monday
# Sunday
# Saturday
# Wednesday
# Thursday
# Friday
# Friday
# Sunday
# Tuesday
# Monday
# Saturday
# Saturday
# Thursday
# Tuesday
# Wednesday
# Tuesday
# Thursday
# Wednesday
# Saturday
# Friday
# Sunday
# Monday
# Friday
# Thursday
# Tuesday
# Wednesday
# Friday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Saturday
# Friday
# Saturday
# Sunday
# Tuesday
# Sunday
# Wednesday
# Monday
# Thursday
# Tuesday
# Wednesday
# Friday
# Saturday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Friday
# Monday
# Sunday
# Wednesday
# Friday
# Saturday
# Monday
# Thursday
# Sunday
# Friday
# Tuesday
# Saturday
# Wednesday
# Monday
# Thursday
# Sunday
# Thursday
# Saturday
# Wednesday
# Tuesday
# Friday
# Thursday
# Sunday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Wednesday
# Friday
# Saturday
# Monday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Monday
# Friday
# Tuesday
# Saturday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Thursday
# Tuesday
# Sunday
# Monday
# Wednesday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Monday
# Tuesday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Friday
# Sunday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Friday
# Saturday
# Friday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Monday
# Thursday
# Saturday
# Monday
# Wednesday
# Wednesday
# Monday
# Thursday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Friday
# Sunday
# Wednesday
# Friday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Wednesday
# Friday
# Sunday
# Friday
# Sunday
# Tuesday
# Wednesday
# Sunday
# Friday
# Tuesday
# Thursday
# Friday
# Wednesday
# Tuesday
# Thursday
# Saturday
# Wednesday
# Monday
# Wednesday
# Thursday
# Saturday
# Monday
# Saturday
# Monday
# Monday
# Saturday
# Sunday
# Saturday
# Monday
# Sunday
# Monday
# Friday
# Monday
# Friday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Saturday
# Thursday
# Wednesday
# Friday
# Wednesday
# Thursday
# Sunday
# Friday
# Wednesday
# Monday
# Tuesday
# Thursday
# Wednesday
# Sunday
# Friday
# Monday
# Thursday
# Saturday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Thursday
# Sunday
# Monday
# Tuesday
# Thursday
# Thursday
# Tuesday
# Saturday
# Monday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Tuesday
# Tuesday
# Sunday
# Monday
# Saturday
# Tuesday
# Saturday
# Tuesday
# Tuesday
# Friday
# Wednesday
# Friday
# Friday
# Sunday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Monday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Monday
# Tuesday
# Saturday
# Sunday
# Monday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Wednesday
# Friday
# Friday
# Saturday
# Sunday
# Friday
# Sunday
# Saturday
# Wednesday
# Monday
# Tuesday
# Sunday
# Thursday
# Friday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Tuesday
# Friday
# Wednesday
# Sunday
# Friday
# Saturday
# Monday
# Thursday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Saturday
# Saturday
# Tuesday
# Monday
# Sunday
# Thursday
# Wednesday
# Friday
# Thursday
# Friday
# Sunday
# Tuesday
# Wednesday
# Saturday
# Thursday
# Sunday
# Saturday
# Friday
# Tuesday
# Wednesday
# Monday
# Saturday
# Tuesday
# Thursday
# Wednesday
# Monday
# Friday
# Tuesday
# Thursday
# Friday
# Wednesday
# Sunday
# Saturday
# Monday
# Thursday
# Tuesday
# Sunday
# Monday
# Wednesday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Saturday
# Friday
# Saturday
# Sunday
# Wednesday
# Monday
# Tuesday
# Sunday
# Monday
# Thursday
# Sunday
# Thursday
# Tuesday
# Wednesday
# Friday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Sunday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Saturday
# Thursday
# Wednesday
# Friday
# Saturday
# Sunday
# Sunday
# Friday
# Tuesday
# Monday
# Wednesday
# Saturday
# Sunday
# Tuesday
# Thursday
# Wednesday
# Monday
# Tuesday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Thursday
# Friday
# Tuesday
# Sunday
# Friday
# Monday
# Wednesday
# Saturday
# Thursday
# Tuesday
# Friday
# Saturday
# Wednesday
# Monday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Friday
# Monday
# Thursday
# Saturday
# Tuesday
# Sunday
# Saturday
# Thursday
# Monday
# Sunday
# Monday
# Saturday
# Wednesday
# Tuesday
# Sunday
# Thursday
# Monday
# Wednesday
# Friday
# Thursday
# Saturday
# Tuesday
# Friday
# Sunday
# Wednesday
# Wednesday
# Saturday
# Thursday
# Monday
# Sunday
# Tuesday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Saturday
# Friday
# Sunday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Sunday
# Tuesday
# Thursday
# Friday
# Saturday
# Monday
# Tuesday
# Friday
# Saturday
# Monday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Sunday
# Friday
# Wednesday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Monday
# Wednesday
# Sunday
# Wednesday
# Thursday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Friday
# Sunday
# Saturday
# Wednesday
# Sunday
# Tuesday
# Thursday
# Monday
# Friday
# Tuesday
# Thursday
# Saturday
# Wednesday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Sunday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Wednesday
# Friday
# Saturday
# Monday
# Monday
# Tuesday
# Sunday
# Thursday
# Wednesday
# Friday
# Monday
# Friday
# Saturday
# Thursday
# Tuesday
# Wednesday
# Wednesday
# Sunday
# Saturday
# Thursday
# Sunday
# Friday
# Tuesday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Monday
# Friday
# Thursday
# Saturday
# Tuesday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Thursday
# Sunday
# Monday
# Tuesday
# Tuesday
# Thursday
# Wednesday
# Friday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Wednesday
# Sunday
# Monday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Sunday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Saturday
# Monday
# Thursday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Friday
# Saturday
# Sunday
# Saturday
# Tuesday
# Friday
# Sunday
# Wednesday
# Monday
# Sunday
# Tuesday
# Thursday
# Monday
# Friday
# Sunday
# Tuesday
# Saturday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Sunday
# Tuesday
# Thursday
# Friday
# Monday
# Thursday
# Sunday
# Friday
# Friday
# Tuesday
# Monday
# Wednesday
# Saturday
# Monday
# Monday
# Thursday
# Wednesday
# Friday
# Wednesday
# Sunday
# Thursday
# Saturday
# Tuesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Friday
# Saturday
# Monday
# Wednesday
# Tuesday
# Sunday
# Thursday
# Wednesday
# Friday
# Monday
# Thursday
# Tuesday
# Saturday
# Sunday
# Friday
# Thursday
# Wednesday
# Saturday
# Monday
# Sunday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Friday
# Thursday
# Wednesday
# Thursday
# Saturday
# Friday
# Sunday
# Saturday
# Sunday
# Tuesday
# Monday
# Wednesday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Monday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Friday
# Sunday
# Tuesday
# Friday
# Wednesday
# Sunday
# Tuesday
# Friday
# Monday
# Saturday
# Tuesday
# Friday
# Wednesday
# Sunday
# Monday
# Wednesday
# Sunday
# Monday
# Saturday
# Thursday
# Friday
# Monday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Saturday
# Tuesday
# Sunday
# Wednesday
# Monday
# Friday
# Wednesday
# Tuesday
# Thursday
# Sunday
# Friday
# Monday
# Wednesday
# Tuesday
# Sunday
# Thursday
# Friday
# Wednesday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Monday
# Saturday
# Wednesday
# Thursday
# Sunday
# Saturday
# Sunday
# Saturday
# Thursday
# Monday
# Sunday
# Friday
# Monday
# Saturday
# Wednesday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Wednesday
# Thursday
# Saturday
# Sunday
# Wednesday
# Monday
# Thursday
# Wednesday
# Saturday
# Thursday
# Thursday
# Tuesday
# Sunday
# Saturday
# Monday
# Tuesday
# Saturday
# Monday
# Thursday
# Wednesday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Friday
# Thursday
# Tuesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Monday
# Tuesday
# Friday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Wednesday
# Friday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Monday
# Tuesday
# Thursday
# Sunday
# Tuesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Saturday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Sunday
# Wednesday
# Friday
# Saturday
# Wednesday
# Saturday
# Thursday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Monday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Monday
# Tuesday
# Sunday
# Friday
# Saturday
# Thursday
# Tuesday
# Sunday
# Friday
# Monday
# Thursday
# Tuesday
# Saturday
# Wednesday
# Sunday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Wednesday
# Friday
# Monday
# Wednesday
# Friday
# Thursday
# Sunday
# Tuesday
# Monday
# Saturday
# Wednesday
# Saturday
# Thursday
# Sunday
# Wednesday
# Friday
# Monday
# Thursday
# Tuesday
# Friday
# Sunday
# Wednesday
# Saturday
# Saturday
# Sunday
# Thursday
# Monday
# Monday
# Tuesday
# Friday
# Wednesday
# Saturday
# Tuesday
# Sunday
# Thursday
# Wednesday
# Friday
# Monday
# Thursday
# Saturday
# Friday
# Sunday
# Saturday
# Thursday
# Monday
# Sunday
# Friday
# Monday
# Tuesday
# Wednesday
# Sunday
# Thursday
# Friday
# Thursday
# Monday
# Saturday
# Tuesday
# Saturday
# Friday
# Sunday
# Sunday
# Tuesday
# Monday
# Wednesday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Tuesday
# Tuesday
# Monday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Friday
# Tuesday
# Friday
# Saturday
# Thursday
# Sunday
# Friday
# Monday
# Tuesday
# Thursday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Sunday
# Monday
# Sunday
# Monday
# Wednesday
# Tuesday
# Wednesday
# Saturday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Thursday
# Tuesday
# Sunday
# Friday
# Monday
# Thursday
# Friday
# Friday
# Thursday
# Sunday
# Tuesday
# Wednesday
# Monday
# Tuesday
# Sunday
# Wednesday
# Saturday
# Monday
# Tuesday
# Friday
# Sunday
# Wednesday
# Thursday
# Sunday
# Monday
# Tuesday
# Saturday
# Tuesday
# Sunday
# Wednesday
# Friday
# Thursday
# Saturday
# Sunday
# Friday
# Sunday
# Tuesday
# Monday
# Saturday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Wednesday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Tuesday
# Thursday
# Friday
# Tuesday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Wednesday
# Thursday
# Tuesday
# Sunday
# Wednesday
# Saturday
# Monday
# Monday
# Saturday
# Thursday
# Friday
# Thursday
# Saturday
# Wednesday
# Thursday
# Friday
# Saturday
# Monday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Monday
# Wednesday
# Thursday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Friday
# Sunday
# Monday
# Wednesday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Monday
# Saturday
# Sunday
# Friday
# Tuesday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Thursday
# Wednesday
# Tuesday
# Saturday
# Sunday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Monday
# Wednesday
# Wednesday
# Friday
# Wednesday
# Saturday
# Thursday
# Sunday
# Tuesday
# Friday
# Friday
# Monday
# Tuesday
# Wednesday
# Saturday
# Thursday
# Sunday
# Saturday
# Friday
# Monday
# Thursday
# Sunday
# Saturday
# Tuesday
# Wednesday
# Sunday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Monday
# Friday
# Thursday
# Tuesday
# Friday
# Sunday
# Wednesday
# Saturday
# Thursday
# Monday
# Tuesday
# Sunday
# Monday
# Tuesday
# Wednesday
# Wednesday
# Thursday
# Monday
# Friday
# Thursday
# Tuesday
# Saturday
# Friday
# Sunday
# Saturday
# Monday
# Sunday
# Tuesday
# Monday
# Wednesday
# Thursday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Monday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Friday
# Saturday
# Sunday
# Friday
# Tuesday
# Saturday
# Wednesday
# Saturday
# Friday
# Sunday
# Thursday
# Monday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Monday
# Thursday
# Monday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Friday
# Monday
# Saturday
# Thursday
# Sunday
# Wednesday
# Thursday
# Sunday
# Saturday
# Tuesday
# Wednesday
# Friday
# Saturday
# Thursday
# Monday
# Sunday
# Friday
# Tuesday
# Monday
# Wednesday
# Saturday
# Tuesday
# Sunday
# Thursday
# Wednesday
# Monday
# Friday
# Thursday
# Saturday
# Tuesday
# Sunday
# Wednesday
# Monday
# Thursday
# Tuesday
# Wednesday
# Friday
# Thursday
# Saturday
# Sunday
# Saturday
# Wednesday
# Monday
# Monday
# Sunday
# Tuesday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Wednesday
# Saturday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Sunday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Wednesday
# Friday
# Thursday
# Wednesday
# Friday
# Saturday
# Friday
# Tuesday
# Saturday
# Sunday
# Monday
# Wednesday
# Tuesday
# Thursday
# Friday
# Monday
# Thursday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Sunday
# Monday
# Friday
# Wednesday
# Sunday
# Wednesday
# Monday
# Saturday
# Sunday
# Friday
# Tuesday
# Friday
# Monday
# Saturday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Monday
# Wednesday
# Tuesday
# Thursday
# Friday
# Wednesday
# Thursday
# Friday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Wednesday
# Monday
# Friday
# Thursday
# Tuesday
# Saturday
# Friday
# Sunday
# Wednesday
# Saturday
# Thursday
# Monday
# Sunday
# Tuesday
# Monday
# Sunday
# Tuesday
# Friday
# Monday
# Thursday
# Saturday
# Friday
# Sunday
# Saturday
# Monday
# Friday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Sunday
# Monday
# Wednesday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Sunday
# Thursday
# Wednesday
# Sunday
# Sunday
# Saturday
# Monday
# Saturday
# Thursday
# Sunday
# Friday
# Thursday
# Wednesday
# Wednesday
# Sunday
# Tuesday
# Monday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Tuesday
# Thursday
# Friday
# Saturday
# Friday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Wednesday
# Friday
# Friday
# Saturday
# Sunday
# Friday
# Sunday
# Tuesday
# Saturday
# Monday
# Wednesday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Friday
# Thursday
# Saturday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Friday
# Monday
# Wednesday
# Sunday
# Friday
# Monday
# Saturday
# Sunday
# Tuesday
# Monday
# Friday
# Saturday
# Tuesday
# Sunday
# Thursday
# Wednesday
# Monday
# Thursday
# Thursday
# Tuesday
# Saturday
# Wednesday
# Friday
# Sunday
# Saturday
# Monday
# Sunday
# Friday
# Tuesday
# Wednesday
# Monday
# Saturday
# Tuesday
# Thursday
# Sunday
# Monday
# Friday
# Thursday
# Saturday
# Tuesday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Monday
# Wednesday
# Thursday
# Wednesday
# Friday
# Thursday
# Saturday
# Friday
# Sunday
# Sunday
# Monday
# Tuesday
# Wednesday
# Monday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Wednesday
# Wednesday
# Tuesday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Tuesday
# Monday
# Sunday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Wednesday
# Saturday
# Tuesday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Monday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Wednesday
# Friday
# Friday
# Saturday
# Sunday
# Sunday
# Friday
# Tuesday
# Monday
# Saturday
# Wednesday
# Thursday
# Sunday
# Tuesday
# Monday
# Wednesday
# Friday
# Tuesday
# Saturday
# Thursday
# Friday
# Sunday
# Wednesday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Monday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Saturday
# Sunday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Friday
# Thursday
# Friday
# Tuesday
# Saturday
# Wednesday
# Tuesday
# Monday
# Thursday
# Sunday
# Friday
# Saturday
# Monday
# Wednesday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Monday
# Friday
# Thursday
# Saturday
# Sunday
# Thursday
# Tuesday
# Friday
# Wednesday
# Saturday
# Monday
# Sunday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Sunday
# Tuesday
# Monday
# Thursday
# Wednesday
# Tuesday
# Wednesday
# Saturday
# Sunday
# Monday
# Wednesday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Wednesday
# Saturday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Tuesday
# Friday
# Thursday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Wednesday
# Friday
# Thursday
# Friday
# Tuesday
# Sunday
# Friday
# Monday
# Saturday
# Wednesday
# Sunday
# Tuesday
# Wednesday
# Friday
# Thursday
# Tuesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Sunday
# Monday
# Thursday
# Monday
# Friday
# Wednesday
# Sunday
# Saturday
# Monday
# Sunday
# Tuesday
# Monday
# Friday
# Monday
# Saturday
# Wednesday
# Friday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Thursday
# Saturday
# Wednesday
# Monday
# Thursday
# Sunday
# Friday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Sunday
# Saturday
# Wednesday
# Friday
# Tuesday
# Thursday
# Friday
# Sunday
# Wednesday
# Monday
# Sunday
# Friday
# Monday
# Saturday
# Tuesday
# Thursday
# Sunday
# Friday
# Monday
# Thursday
# Saturday
# Sunday
# Sunday
# Friday
# Monday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Saturday
# Sunday
# Monday
# Wednesday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Tuesday
# Sunday
# Saturday
# Saturday
# Thursday
# Monday
# Thursday
# Saturday
# Tuesday
# Wednesday
# Wednesday
# Friday
# Saturday
# Monday
# Tuesday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Tuesday
# Thursday
# Friday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Sunday
# Monday
# Wednesday
# Monday
# Thursday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Wednesday
# Friday
# Monday
# Friday
# Sunday
# Tuesday
# Saturday
# Wednesday
# Tuesday
# Sunday
# Thursday
# Wednesday
# Friday
# Monday
# Tuesday
# Saturday
# Thursday
# Monday
# Thursday
# Saturday
# Sunday
# Monday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Sunday
# Tuesday
# Wednesday
# Friday
# Monday
# Saturday
# Saturday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Monday
# Friday
# Thursday
# Friday
# Wednesday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Tuesday
# Sunday
# Wednesday
# Friday
# Thursday
# Monday
# Saturday
# Tuesday
# Friday
# Sunday
# Wednesday
# Thursday
# Monday
# Sunday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Friday
# Thursday
# Tuesday
# Saturday
# Friday
# Wednesday
# Sunday
# Saturday
# Sunday
# Friday
# Monday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Tuesday
# Wednesday
# Thursday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Tuesday
# Friday
# Saturday
# Sunday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Tuesday
# Sunday
# Saturday
# Monday
# Saturday
# Thursday
# Saturday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Friday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Tuesday
# Wednesday
# Monday
# Wednesday
# Friday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Sunday
# Monday
# Friday
# Saturday
# Saturday
# Sunday
# Monday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Sunday
# Friday
# Tuesday
# Saturday
# Monday
# Wednesday
# Tuesday
# Tuesday
# Monday
# Friday
# Wednesday
# Thursday
# Saturday
# Monday
# Tuesday
# Thursday
# Saturday
# Monday
# Sunday
# Monday
# Friday
# Friday
# Wednesday
# Sunday
# Monday
# Saturday
# Sunday
# Friday
# Tuesday
# Monday
# Wednesday
# Saturday
# Thursday
# Sunday
# Wednesday
# Thursday
# Saturday
# Wednesday
# Thursday
# Sunday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Thursday
# Sunday
# Friday
# Monday
# Saturday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Friday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Thursday
# Sunday
# Tuesday
# Wednesday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Thursday
# Saturday
# Tuesday
# Wednesday
# Friday
# Saturday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Thursday
# Tuesday
# Tuesday
# Friday
# Sunday
# Monday
# Friday
# Saturday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Thursday
# Wednesday
# Friday
# Wednesday
# Saturday
# Sunday
# Friday
# Monday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Monday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Saturday
# Monday
# Wednesday
# Friday
# Sunday
# Monday
# Thursday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Tuesday
# Friday
# Sunday
# Wednesday
# Saturday
# Sunday
# Tuesday
# Thursday
# Monday
# Friday
# Saturday
# Tuesday
# Friday
# Thursday
# Sunday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Sunday
# Monday
# Monday
# Wednesday
# Friday
# Thursday
# Saturday
# Monday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Monday
# Sunday
# Wednesday
# Friday
# Monday
# Thursday
# Wednesday
# Saturday
# Tuesday
# Sunday
# Saturday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Saturday
# Wednesday
# Tuesday
# Sunday
# Thursday
# Wednesday
# Monday
# Friday
# Tuesday
# Thursday
# Saturday
# Friday
# Wednesday
# Sunday
# Saturday
# Thursday
# Monday
# Sunday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Thursday
# Wednesday
# Friday
# Thursday
# Saturday
# Friday
# Sunday
# Saturday
# Monday
# Friday
# Monday
# Tuesday
# Wednesday
# Saturday
# Thursday
# Tuesday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Saturday
# Friday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# ...
# Sunday
# Saturday
# Monday
# Friday
# Tuesday
# Monday
# Tuesday
# Thursday
# Saturday
# Sunday
# Monday
# Wednesday
# Saturday
# Sunday
# Friday
# Wednesday
# Monday
# Saturday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Monday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Friday
# Thursday
# Friday
# Wednesday
# Thursday
# Sunday
# Tuesday
# Sunday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Wednesday
# Friday
# Monday
# Sunday
# Saturday
# Tuesday
# Wednesday
# Monday
# Thursday
# Sunday
# Monday
# Tuesday
# Tuesday
# Thursday
# Thursday
# Friday
# Wednesday
# Saturday
# Sunday
# Monday
# Sunday
# Friday
# Monday
# Thursday
# Thursday
# Sunday
# Monday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Saturday
# Monday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Tuesday
# Sunday
# Saturday
# Monday
# Saturday
# Thursday
# Friday
# Saturday
# Wednesday
# Wednesday
# Friday
# Saturday
# Tuesday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Friday
# Saturday
# Tuesday
# Wednesday
# Monday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Tuesday
# Friday
# Sunday
# Wednesday
# Tuesday
# Saturday
# Monday
# Wednesday
# Thursday
# Sunday
# Wednesday
# Friday
# Monday
# Tuesday
# Thursday
# Saturday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Friday
# Monday
# Wednesday
# Saturday
# Tuesday
# Monday
# Thursday
# Sunday
# Friday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Monday
# Thursday
# Saturday
# Tuesday
# Friday
# Wednesday
# Sunday
# Saturday
# Thursday
# Monday
# Friday
# Sunday
# Tuesday
# Monday
# Saturday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Friday
# Monday
# Thursday
# Thursday
# Saturday
# Tuesday
# Friday
# Sunday
# Wednesday
# Saturday
# Wednesday
# Monday
# Sunday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Monday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Tuesday
# Wednesday
# Friday
# Sunday
# Monday
# Wednesday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Monday
# Friday
# Sunday
# Monday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Wednesday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Saturday
# Tuesday
# Friday
# Thursday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Sunday
# Tuesday
# Friday
# Wednesday
# Saturday
# Monday
# Wednesday
# Tuesday
# Thursday
# Monday
# Wednesday
# Friday
# Tuesday
# Thursday
# Saturday
# Sunday
# Monday
# Thursday
# Wednesday
# Monday
# Thursday
# Wednesday
# Sunday
# Monday
# Wednesday
# Tuesday
# Thursday
# Monday
# Wednesday
# Saturday
# Wednesday
# Friday
# Monday
# Sunday
# Tuesday
# Wednesday
# Saturday
# Thursday
# Friday
# Monday
# Sunday
# Friday
# Wednesday
# Friday
# Sunday
# Thursday
# Saturday
# Friday
# Monday
# Wednesday
# Saturday
# Sunday
# Wednesday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Saturday
# Monday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Sunday
# Saturday
# Friday
# Saturday
# Monday
# Sunday
# Tuesday
# Friday
# Tuesday
# Friday
# Thursday
# Saturday
# Tuesday
# Friday
# Sunday
# Saturday
# Monday
# Sunday
# Friday
# Thursday
# Tuesday
# Sunday
# Thursday
# Saturday
# Friday
# Tuesday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Monday
# Tuesday
# Thursday
# Saturday
# Tuesday
# Thursday
# Wednesday
# Monday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Saturday
# Friday
# Thursday
# Sunday
# Monday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Monday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Tuesday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Tuesday
# Sunday
# Friday
# Monday
# Wednesday
# Friday
# Tuesday
# Thursday
# Wednesday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Thursday
# Saturday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Monday
# Friday
# Thursday
# Tuesday
# Saturday
# Friday
# Wednesday
# Sunday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Friday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Sunday
# Wednesday
# Friday
# Monday
# Tuesday
# Thursday
# Saturday
# Friday
# Sunday
# Wednesday
# Saturday
# Monday
# Thursday
# Sunday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Friday
# Thursday
# Wednesday
# Thursday
# Monday
# Saturday
# Saturday
# Sunday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Tuesday
# Wednesday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Thursday
# Friday
# Saturday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Sunday
# Friday
# Tuesday
# Sunday
# Saturday
# Wednesday
# Tuesday
# Sunday
# Wednesday
# Monday
# Friday
# Tuesday
# Saturday
# Wednesday
# Friday
# Sunday
# Monday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Thursday
# Sunday
# Monday
# Sunday
# Tuesday
# Friday
# Saturday
# Wednesday
# Sunday
# Wednesday
# Friday
# Saturday
# Wednesday
# Saturday
# Monday
# Friday
# Monday
# Sunday
# Monday
# Thursday
# Tuesday
# Friday
# Saturday
# Thursday
# Sunday
# Wednesday
# Friday
# Monday
# Saturday
# Monday
# Thursday
# Saturday
# Sunday
# Monday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Friday
# Sunday
# Monday
# Tuesday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Saturday
# Thursday
# Monday
# Thursday
# Tuesday
# Monday
# Thursday
# Tuesday
# Friday
# Thursday
# Tuesday
# Sunday
# Wednesday
# Saturday
# Thursday
# Tuesday
# Friday
# Wednesday
# Saturday
# Sunday
# Wednesday
# Monday
# Tuesday
# Monday
# Wednesday
# Saturday
# Tuesday
# Sunday
# Thursday
# Thursday
# Saturday
# Tuesday
# Friday
# Sunday
# Tuesday
# Wednesday
# Saturday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Monday
# Wednesday
# Thursday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Tuesday
# Wednesday
# Wednesday
# Thursday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Friday
# Tuesday
# Monday
# Saturday
# Friday
# Sunday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Sunday
# Monday
# Wednesday
# Friday
# Thursday
# Saturday
# Monday
# Sunday
# Monday
# Friday
# Tuesday
# Monday
# Wednesday
# Saturday
# Tuesday
# Thursday
# Wednesday
# Friday
# Thursday
# Sunday
# Saturday
# Tuesday
# Friday
# Wednesday
# Saturday
# Thursday
# Monday
# Friday
# Sunday
# Tuesday
# Monday
# Tuesday
# Saturday
# Wednesday
# Thursday
# Sunday
# Wednesday
# Friday
# Monday
# Thursday
# Saturday
# Tuesday
# Friday
# Wednesday
# Sunday
# Saturday
# Thursday
# Monday
# Sunday
# Tuesday
# Monday
# Wednesday
# Tuesday
# Sunday
# Thursday
# Wednesday
# Thursday
# Friday
# Monday
# Saturday
# Friday
# Sunday
# Saturday
# Sunday
# Wednesday
# Tuesday
# Monday
# Thursday
# Tuesday
# Wednesday
# Friday
# Saturday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Saturday
# Monday
# Wednesday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Sunday
# Wednesday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Sunday
# Friday
# Sunday
# Tuesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Wednesday
# Thursday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Friday
# Wednesday
# Saturday
# Sunday
# Thursday
# Monday
# Friday
# Saturday
# Tuesday
# Sunday
# Wednesday
# Monday
# Thursday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Tuesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Friday
# Monday
# Tuesday
# Wednesday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Monday
# Wednesday
# Thursday
# Friday
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Wednesday
# Monday
# Monday
# Wednesday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Thursday
# Friday
# Saturday
# Thursday
# Saturday
# Sunday
# Sunday
# Monday
# Monday
# Tuesday
# Wednesday
# Tuesday
# Friday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Monday
# Tuesday
# Wednesday
# Friday
# Saturday
# Sunday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
# Monday
# Tuesday
# Wednesday

# %% [markdown]
# Meistens kann man die apply Funktion für solche Fälle nutzen, also wenn man für jeden Wert oder jede Reihe etwas anwenden will.
# Konkret im unteren Beispiel wird `apply(lambda x: get_weekday(x))` für jeden Wert in `df_raw['phenomenonTime']` angewendet und `return weekday`. Das kann dann einfach in eine neue Spalte gespeichert werden (siehe df['weekday'], dieser Key muss vorher nicht existieren)

# %%
# Dein Code nur als Funktion
def get_weekday(input_date):
    t = input_date[25:35]
    day = pd.Timestamp(t)
    weekday = day.day_name()
    return weekday

# %%
# lass das laufen und du siehst was der Output ist
# ich nutze df_raw_test, damit das etwas schneller ist
df_raw_test['phenomenonTime'].apply(lambda x: get_weekday(x))
# Out:
# 0        Friday
# 1      Saturday
# 2        Sunday
# 3        Sunday
# 4       Tuesday
#          ...
# 126      Friday
# 127    Saturday
# 128      Sunday
# 129      Friday
# 130    Saturday
# Name: phenomenonTime, Length: 131, dtype: object

# %% [markdown]
# ## Debug Ende

# %%
# neue Spalte im Dataframe
df_raw['weekday'] = df_raw['phenomenonTime'].apply(lambda x: get_weekday(x))

# %%
df_raw.head()
# Out:
#      @iot.id                                     phenomenonTime  result  \
# 0  217458399  2021-08-11T22:00:00.000Z/2021-08-12T21:59:59.000Z    1090
# 1  216650904  2021-08-10T22:00:00.000Z/2021-08-11T21:59:59.000Z    1040
# 2  219332283  2021-08-12T22:00:00.000Z/2021-08-13T21:59:59.000Z    1013
# 3   51222146  2021-01-21T23:00:00.000Z/2021-01-22T22:59:59.000Z    7831
# 4   51496408  2021-01-22T23:00:00.000Z/2021-01-23T22:59:59.000Z    5187
#
#                  resultTime     id        lat       long    weekday
# 0  2021-08-13T01:47:21.106Z  15808  53.650597   9.949614   Thursday
# 1  2021-08-12T01:47:21.810Z  15808  53.650597   9.949614  Wednesday
# 2  2021-08-14T01:47:51.680Z  15808  53.650597   9.949614     Friday
# 3  2021-01-23T01:47:30.603Z  14812  53.628402  10.140319     Friday
# 4  2021-01-24T01:50:38.217Z  14812  53.628402  10.140319   Saturday

# %% [markdown]
# Maren
# Goal: Create "clean" csv file, so everyone can work with that from now on
#
# advantages:
# - no useless columns anymore
# - the downloaded data/dates don´t change any more
# - otherwise with every time running the codes a dataset with daily updated data occurs, which might confuse our results

# %%
# convert the dates to a correct format
phenomenonTime = df_raw["phenomenonTime"]

phenomenonTime=phenomenonTime.astype(str)
phenomenonDate=phenomenonTime.str.replace("(.*)\/", "", regex = True)
phenomenonDate=phenomenonDate.str.replace("T(.*)", "", regex = True)

df_raw["phenomenonDate"] = pd.to_datetime(phenomenonDate)

# %%
df_raw.dtypes
# Out:
# @iot.id                   object
# phenomenonTime            object
# result                     int64
# resultTime                object
# id                         int64
# lat                      float64
# long                     float64
# weekday                   object
# phenomenonDate    datetime64[ns]
# dtype: object

# %%
# Keep only relevant columns
columns = ['@iot.id','phenomenonDate', 'result','id','lat','long','weekday']

# %%
df_raw = df_raw[columns]

# %%
df_raw
# Out:
#           @iot.id phenomenonDate  result     id        lat       long  \
# 0       217458399     2021-08-12    1090  15808  53.650597   9.949614
# 1       216650904     2021-08-11    1040  15808  53.650597   9.949614
# 2       219332283     2021-08-13    1013  15808  53.650597   9.949614
# 3        51222146     2021-01-22    7831  14812  53.628402  10.140319
# 4        51496408     2021-01-23    5187  14812  53.628402  10.140319
# ...           ...            ...     ...    ...        ...        ...
# 121647  207523877     2021-07-31    4156  14412  53.530336  10.065717
# 121648  208617775     2021-08-01    2851  14412  53.530336  10.065717
# 121649  210239080     2021-08-02    4901  14412  53.530336  10.065717
# 121650  211949905     2021-08-03    4572  14412  53.530336  10.065717
# 121651  213887390     2021-08-04    5272  14412  53.530336  10.065717
#
#           weekday
# 0        Thursday
# 1       Wednesday
# 2          Friday
# 3          Friday
# 4        Saturday
# ...           ...
# 121647   Saturday
# 121648     Sunday
# 121649     Monday
# 121650    Tuesday
# 121651  Wednesday
#
# [121652 rows x 7 columns]

# %% [markdown]
# Maren: Clean rest of the dataset
# - Are there results with 0 ? --> Drop
# - Are there duplicates in Zählstellen/ phenomenondate? --> Drop one of them

# %%
#drop all observations which have 0 as result
df_raw[df_raw.result!=0]
# Out:
#           @iot.id phenomenonDate  result     id        lat       long  \
# 0       217458399     2021-08-12    1090  15808  53.650597   9.949614
# 1       216650904     2021-08-11    1040  15808  53.650597   9.949614
# 2       219332283     2021-08-13    1013  15808  53.650597   9.949614
# 3        51222146     2021-01-22    7831  14812  53.628402  10.140319
# 4        51496408     2021-01-23    5187  14812  53.628402  10.140319
# ...           ...            ...     ...    ...        ...        ...
# 121647  207523877     2021-07-31    4156  14412  53.530336  10.065717
# 121648  208617775     2021-08-01    2851  14412  53.530336  10.065717
# 121649  210239080     2021-08-02    4901  14412  53.530336  10.065717
# 121650  211949905     2021-08-03    4572  14412  53.530336  10.065717
# 121651  213887390     2021-08-04    5272  14412  53.530336  10.065717
#
#           weekday
# 0        Thursday
# 1       Wednesday
# 2          Friday
# 3          Friday
# 4        Saturday
# ...           ...
# 121647   Saturday
# 121648     Sunday
# 121649     Monday
# 121650    Tuesday
# 121651  Wednesday
#
# [121318 rows x 7 columns]

# %%
#find problematic observations
#Are there duplicates in combination Zählstellen/ phenomenondate? 


## pivot: count numbers of Zählstellen("id") per phenomenondate --> saved as CountZählstelle
CountZaehlstelle = df_raw.pivot_table(values = "id", index = "phenomenonDate", aggfunc= "count")

import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data=CountZaehlstelle, x = "phenomenonDate", y = "id")

CountZaehlstelle
## find the problematic dates: There were measured almost double the Zählstellen than on the other dates
CountZaehlstelle[CountZaehlstelle.id > 500]
# Out:
#                  id
# phenomenonDate
# 2021-03-27      853
# 2021-07-01      790

# %%
##--> problematic dates are: 2021-03-27 and 2021-07-01
Problemdata_a = df_raw[df_raw.phenomenonDate == "2021-03-27"]
Problemdata_b = df_raw[df_raw.phenomenonDate == "2021-07-01"]

## pivot: Find out whether the 2 entries for every Zählstelle on 2021-03-27 and 2021-07-01 are so close together that we can just drop one of each
Problemdata_apiv = Problemdata_a.pivot_table(values = "result", index = "id", aggfunc = lambda x: max(x) - min(x))
Problemdata_apiv[Problemdata_apiv.result > 100]
# Out:
#        result
# id
# 12904     420
# 13228     165
# 13232     106
# 13908     111
# 14636     114

# %%
Problemdata_bpiv = Problemdata_b.pivot_table(values = "result", index = "id", aggfunc = lambda x: max(x) - min(x))
Problemdata_bpiv[Problemdata_bpiv.result > 100]

##--> result: yes, we can drop duplicates in the dataset according to id/phenomenonDate 
## because the difference in result between the duplicates is not so big
# Out:
# Empty DataFrame
# Columns: [result]
# Index: []

# %%
#drop duplicates
df_raw=df_raw.drop_duplicates(['phenomenonDate','id'],keep= 'first')

# %%
## pivot: count numbers of Zählstellen("id") per phenomenondate 
CountZaehlstelle_final = df_raw.pivot_table(values = "id", index = "phenomenonDate", aggfunc= "count")


sns.lineplot(data=CountZaehlstelle_final, x = "phenomenonDate", y = "id")
# Out:
# <AxesSubplot:xlabel='phenomenonDate', ylabel='id'>

# %%
#save in csv format
df_raw.to_csv(r'C:\Users\Maren\Desktop\TechLabs\hh_techlabs_group12\hh_techlabs_group12\clean_data_2021-08-14.csv',index=False)
