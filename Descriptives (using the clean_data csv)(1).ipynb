# %% [markdown]
# # Descriptives (using the csv file)

# %%
import json
import pandas as pd
import requests
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#get the csv

# %%
df_clean_data = pd.read_csv(r'C:\Users\Maren\Desktop\TechLabs\hh_techlabs_group12\hh_techlabs_group12\clean_data_2021-08-14.csv')

# %%
df_clean_data
# Out:
#           @iot.id phenomenonDate  result     id        lat       long  \
# 0       217458399     2021-08-12    1090  15808  53.650597   9.949614
# 1       216650904     2021-08-11    1040  15808  53.650597   9.949614
# 2       219332283     2021-08-13    1013  15808  53.650597   9.949614
# 3        51222146     2021-01-22    7831  14812  53.628402  10.140319
# 4        51496408     2021-01-23    5187  14812  53.628402  10.140319
# ...           ...            ...     ...    ...        ...        ...
# 120804  207523877     2021-07-31    4156  14412  53.530336  10.065717
# 120805  208617775     2021-08-01    2851  14412  53.530336  10.065717
# 120806  210239080     2021-08-02    4901  14412  53.530336  10.065717
# 120807  211949905     2021-08-03    4572  14412  53.530336  10.065717
# 120808  213887390     2021-08-04    5272  14412  53.530336  10.065717
#
#           weekday
# 0        Thursday
# 1       Wednesday
# 2          Friday
# 3          Friday
# 4        Saturday
# ...           ...
# 120804   Saturday
# 120805     Sunday
# 120806     Monday
# 120807    Tuesday
# 120808  Wednesday
#
# [120809 rows x 7 columns]

# %%
df_clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120809 entries, 0 to 120808
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   @iot.id         120809 non-null  int64
#  1   phenomenonDate  120809 non-null  object
#  2   result          120809 non-null  int64
#  3   id              120809 non-null  int64
#  4   lat             120809 non-null  float64
#  5   long            120809 non-null  float64
#  6   weekday         120809 non-null  object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 6.5+ MB

# %%
df_clean_data.dtypes
# Out:
# @iot.id             int64
# phenomenonDate     object
# result              int64
# id                  int64
# lat               float64
# long              float64
# weekday            object
# dtype: object

# %%
#  I would like to change phenomenonDate back to the format datetime64 (this got lost when saving the file as csv)

# %%
df_clean_data=df_clean_data.astype({'phenomenonDate': 'datetime64'})

# %%
df_clean_data.dtypes
# Out:
# @iot.id                    int64
# phenomenonDate    datetime64[ns]
# result                     int64
# id                         int64
# lat                      float64
# long                     float64
# weekday                   object
# dtype: object

# %%
#min/max values

df_clean_data.max()
# Out:
# @iot.id                     219332820
# phenomenonDate    2021-08-13 00:00:00
# result                         103236
# id                              15892
# lat                           53.6808
# long                          10.2165
# weekday                     Wednesday
# dtype: object

# %%
df_clean_data.min()
# Out:
# @iot.id                      51216915
# phenomenonDate    2020-11-01 00:00:00
# result                              0
# id                              12904
# lat                           53.4196
# long                          9.73555
# weekday                        Friday
# dtype: object

# %%
df_clean_data.loc[df_clean_data["result"]==0]
# Out:
#          @iot.id phenomenonDate  result     id        lat       long   weekday
# 35505   57532591     2021-02-21       0  14648  53.583577   9.984033    Sunday
# 35511   58820174     2021-02-27       0  14648  53.583577   9.984033  Saturday
# 35513   59230729     2021-03-01       0  14648  53.583577   9.984033    Monday
# 51192   51839773     2020-12-01       0  14836  53.598878   9.991415   Tuesday
# 51194   51840064     2020-11-01       0  14836  53.598878   9.991415    Sunday
# ...          ...            ...     ...    ...        ...        ...       ...
# 117625  67002239     2021-04-05       0  14856  53.557454  10.033140    Monday
# 117626  65377816     2021-03-28       0  14856  53.557454  10.033140    Sunday
# 117631  68002083     2021-04-09       0  14856  53.557454  10.033140    Friday
# 117632  68123034     2021-04-10       0  14856  53.557454  10.033140  Saturday
# 117633  68235649     2021-04-11       0  14856  53.557454  10.033140    Sunday
#
# [333 rows x 7 columns]

# %%
#drop all observations which have 0 as result
df_clean_data=df_clean_data[df_clean_data.result!=0]

# %%
### --> range of dates: From 2020-11-01 to 2021-08-13 the vehicles are counted

# %%
# How many Zählstellen are measuring every day? 

## pivot: count numbers of Zählstellen("id") per phenomenondate
CountZaehlstelle = df_clean_data.pivot_table(values = "id", index = "phenomenonDate", aggfunc= "count")
CountZaehlstelle
# Out:
#                  id
# phenomenonDate
# 2020-11-01      413
# 2020-11-02      413
# 2020-11-03      414
# 2020-11-04      414
# 2020-11-05      420
# ...             ...
# 2021-08-09      370
# 2021-08-10      382
# 2021-08-11      411
# 2021-08-12      416
# 2021-08-13      414
#
# [286 rows x 1 columns]

# %%
sns.lineplot(data=CountZaehlstelle, x = "phenomenonDate", y = "id")
# Out:
# <AxesSubplot:xlabel='phenomenonDate', ylabel='id'>

# %%
# Combined number of cars measured each individual day
SumCars = df_clean_data.pivot_table(values = "result", index = "phenomenonDate", aggfunc = "sum")
SumCars
# Out:
#                  result
# phenomenonDate
# 2020-11-01      3103401
# 2020-11-02      5224876
# 2020-11-03      5351141
# 2020-11-04      5298766
# 2020-11-05      5332135
# ...                 ...
# 2021-08-09      5162366
# 2021-08-10      5337259
# 2021-08-11      6138216
# 2021-08-12      6198883
# 2021-08-13      6132723
#
# [286 rows x 1 columns]

# %%
#Cars in Summer (summer holidays 24.6.-4.8.--> Look at July) vs. winter (December until 4th Jan (end of holidays))
# create new dataset with only those months

#Summer
start_date = '2021-07-01'
end_date = '2021-07-30'

mask = (df_clean_data['phenomenonDate'] > start_date) & (df_clean_data['phenomenonDate'] <= end_date)

df_clean_data_summer = df_clean_data.loc[mask]

df_clean_data_summer
# Out:
#           @iot.id phenomenonDate  result     id        lat       long  \
# 255     164293050     2021-07-02    7891  14812  53.628402  10.140319
# 256     165919656     2021-07-03    5748  14812  53.628402  10.140319
# 257     167354287     2021-07-04    4427  14812  53.628402  10.140319
# 258     168996471     2021-07-05    7463  14812  53.628402  10.140319
# 259     170415667     2021-07-06    7443  14812  53.628402  10.140319
# ...           ...            ...     ...    ...        ...        ...
# 120799  200163128     2021-07-26    5603  14412  53.530336  10.065717
# 120800  201599678     2021-07-27    5896  14412  53.530336  10.065717
# 120801  203232443     2021-07-28    5530  14412  53.530336  10.065717
# 120802  204917074     2021-07-29    5978  14412  53.530336  10.065717
# 120803  206285717     2021-07-30    5352  14412  53.530336  10.065717
#
#           weekday
# 255        Friday
# 256      Saturday
# 257        Sunday
# 258        Monday
# 259       Tuesday
# ...           ...
# 120799     Monday
# 120800    Tuesday
# 120801  Wednesday
# 120802   Thursday
# 120803     Friday
#
# [11464 rows x 7 columns]

# %%
SumCars_summer = df_clean_data_summer.pivot_table(values = "result", index = "phenomenonDate", aggfunc = "sum")
SumCars_summer
# Out:
#                  result
# phenomenonDate
# 2021-07-02      5470977
# 2021-07-03      4193320
# 2021-07-04      3343551
# 2021-07-05      5244522
# 2021-07-06      5310661
# 2021-07-07      5375531
# 2021-07-08      5410197
# 2021-07-09      5293476
# 2021-07-10      4114963
# 2021-07-11      3199061
# 2021-07-12      5007099
# 2021-07-13      5129229
# 2021-07-14      5287896
# 2021-07-15      5357593
# 2021-07-16      5352629
# 2021-07-17      4179447
# 2021-07-18      3322996
# 2021-07-19      5074405
# 2021-07-20      5098343
# 2021-07-21      5116489
# 2021-07-22      5178664
# 2021-07-23      4979812
# 2021-07-24      3849409
# 2021-07-25      3168703
# 2021-07-26      4885003
# 2021-07-27      5052919
# 2021-07-28      5102761
# 2021-07-29      5272981
# 2021-07-30      5278423

# %%
SumCars_summer.reset_index(level=0, inplace=True)

# %%
SumCars_summer.dtypes
# Out:
# phenomenonDate    datetime64[ns]
# result                     int64
# dtype: object

# %%
sns.barplot(x="phenomenonDate", y="result", data=SumCars_summer)
# Out:
# <AxesSubplot:xlabel='phenomenonDate', ylabel='result'>

# %%
SumCars_summer.max()
# Out:
# phenomenonDate    2021-07-30 00:00:00
# result                        5470977
# dtype: object

# %%
SumCars_summer.min()
# Out:
# phenomenonDate    2021-07-02 00:00:00
# result                        3168703
# dtype: object

# %%
#Winter 
start_date_winter = '2020-12-01'
end_date_winter = '2021-01-04'

mask_winter = (df_clean_data['phenomenonDate'] > start_date_winter) & (df_clean_data['phenomenonDate'] <= end_date_winter)

df_clean_data_winter = df_clean_data.loc[mask_winter]

df_clean_data_winter
# Out:
#          @iot.id phenomenonDate  result     id        lat       long  \
# 6       51839722     2021-01-01    2829  14812  53.628402  10.140319
# 9       51845703     2021-01-02    4340  14812  53.628402  10.140319
# 11      51850923     2020-12-03    9121  14812  53.628402  10.140319
# 12      51851403     2021-01-03    3388  14812  53.628402  10.140319
# 13      51862133     2020-12-05    6386  14812  53.628402  10.140319
# ...          ...            ...     ...    ...        ...        ...
# 120610  53683196     2020-12-27    1372  14412  53.530336  10.065717
# 120611  53687056     2020-12-28    3393  14412  53.530336  10.065717
# 120612  53690537     2020-12-29    3370  14412  53.530336  10.065717
# 120613  53693612     2020-12-30    3500  14412  53.530336  10.065717
# 120614  53697160     2020-12-31    2299  14412  53.530336  10.065717
#
#           weekday
# 6          Friday
# 9        Saturday
# 11       Thursday
# 12         Sunday
# 13       Saturday
# ...           ...
# 120610     Sunday
# 120611     Monday
# 120612    Tuesday
# 120613  Wednesday
# 120614   Thursday
#
# [14815 rows x 7 columns]

# %%
SumCars_winter = df_clean_data_winter.pivot_table(values = "result", index = "phenomenonDate", aggfunc = "sum")
SumCars_winter
# Out:
#                  result
# phenomenonDate
# 2020-12-02      5521792
# 2020-12-03      5583759
# 2020-12-04      5625966
# 2020-12-05      3982856
# 2020-12-06      2702509
# 2020-12-07      5304718
# 2020-12-08      5626378
# 2020-12-09      5586877
# 2020-12-10      5673543
# 2020-12-11      5729774
# 2020-12-12      4028507
# 2020-12-13      2571306
# 2020-12-14      5890985
# 2020-12-15      5983060
# 2020-12-16      5112659
# 2020-12-17      5267168
# 2020-12-18      5442694
# 2020-12-19      3840928
# 2020-12-20      2716200
# 2020-12-21      5137736
# 2020-12-22      5170657
# 2020-12-23      4896814
# 2020-12-24      3317838
# 2020-12-25      2726869
# 2020-12-26      2538881
# 2020-12-27      2307736
# 2020-12-28      4178788
# 2020-12-29      4291113
# 2020-12-30      4478484
# 2020-12-31      3057725
# 2021-01-01      2114569
# 2021-01-02      2943923
# 2021-01-03      2532325
# 2021-01-04      4756934

# %%
SumCars_winter.reset_index(level=0, inplace=True)

# %%
sns.barplot(x="phenomenonDate", y="result", data=SumCars_winter)
# Out:
# <AxesSubplot:xlabel='phenomenonDate', ylabel='result'>

# %%
SumCars_winter.min()
# Out:
# phenomenonDate    2020-12-02 00:00:00
# result                        2114569
# dtype: object

# %%
SumCars_winter.loc[SumCars_winter["result"]==2114569]
# Out:
#    phenomenonDate   result
# 30     2021-01-01  2114569

# %%
##--> am 01.01.2021 am wenigsten Autos um Weihnachten rum

# %%
SumCars_winter.max()
# Out:
# phenomenonDate    2021-01-04 00:00:00
# result                        5983060
# dtype: object

# %%
SumCars_winter.loc[SumCars_winter["result"]==5983060]
# Out:
#    phenomenonDate   result
# 13     2020-12-15  5983060

# %%
# How much traffic is there all combined every day?
sns.catplot(x="phenomenonDate", y="result", data = df_clean_data, height=8, aspect=2.5)

# %%
# Amount of cars per weekday
sns.catplot(x="weekday", y="result", data = df_clean_data, height=8)

# %%
# Another way for visualiszation is using a boxplot. 
sns.catplot(x="weekday", y="result", kind="box", data=df_clean_data, height = 8)

# %%
# Calculating the average of each weekday
df_clean_data_mean=df_clean_data.groupby(['weekday']).mean()

# %%
df_clean_data_mean
# Out:
#                 @iot.id        result            id        lat       long
# weekday
# Friday     9.287463e+07  12697.618640  13884.032185  53.573144  10.007551
# Monday     9.011863e+07  12384.778197  13879.467904  53.573155  10.007550
# Saturday   9.019648e+07   9303.280036  13879.508514  53.573118  10.007594
# Sunday     8.964676e+07   7157.507058  13878.535231  53.573114  10.007555
# Thursday   9.216136e+07  12794.976255  13884.373447  53.573153  10.007410
# Tuesday    9.069728e+07  12896.377504  13879.874030  53.573114  10.007424
# Wednesday  9.150572e+07  12950.962839  13883.800497  53.573168  10.007486

# %%
df_clean_data_mean.reset_index(level=0, inplace=True)

# %%
order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday","Sunday"]

# %%
sns.barplot(x="weekday", y="result", data=df_clean_data_mean, order=order)
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='result'>

# %%
# Convert single digit weeknumbers to 2-digit weeknumbers (e.g "5" to "05")
# Weeknumbers

df_clean_data["Weeknumber"] = df_clean_data["phenomenonDate"].apply(lambda x: x.isocalendar()[1])
df_clean_data["yearnumber"] = df_clean_data["phenomenonDate"].apply(lambda x: x.isocalendar()[0])

# %%
def convert_weekno(num_weeknumber):
    if len(str(num_weeknumber)) == 1:
        Weeknumber_clean = '0'+str(num_weeknumber)
    else:
        Weeknumber_clean = str(num_weeknumber)
    return(Weeknumber_clean)

df_clean_data["Weeknumberstring"] = df_clean_data["Weeknumber"].apply(lambda x: convert_weekno(x))

# %%
df_clean_data["yearnumber"]=df_clean_data["yearnumber"].astype(object)

# %%
# Combine year + weeknumber
df_clean_data["Week in year"] = df_clean_data["yearnumber"].map(str)+df_clean_data["Weeknumberstring"].map(str)

# %%
df_clean_data["Week in year"]
# Out:
# 0         202132
# 1         202132
# 2         202132
# 3         202103
# 4         202103
#            ...
# 120804    202130
# 120805    202130
# 120806    202131
# 120807    202131
# 120808    202131
# Name: Week in year, Length: 120476, dtype: object

# %%
df_clean_data.dtypes
# Out:
# @iot.id                      int64
# phenomenonDate      datetime64[ns]
# result                       int64
# id                           int64
# lat                        float64
# long                       float64
# weekday                     object
# Weeknumber                   int64
# yearnumber                  object
# Weeknumberstring            object
# Week in year                object
# dtype: object

# %%
df_clean_data["Week in year"]=df_clean_data["Week in year"].astype(int)

# %%
#Calculating the average of each week:
df_clean_data_weekmean=df_clean_data.groupby(['Week in year']).mean()

# %%
df_clean_data_weekmean
# Out:
#                    @iot.id        result            id        lat       long  \
# Week in year
# 202044        5.187067e+07   7514.288136  13850.702179  53.572252  10.008534
# 202045        5.261274e+07  11463.883459  13856.084757  53.572378  10.008299
# 202046        5.376121e+07  11482.457240  13865.170698  53.573255  10.007174
# 202047        5.378054e+07  11364.189921  13858.062393  53.573725  10.007771
# 202048        5.395078e+07  11748.665075  13855.245566  53.573051  10.007652
# 202049        5.239951e+07  11609.371255  13859.457422  53.572583  10.006870
# 202050        5.375958e+07  11445.989058  13861.249337  53.572626  10.006873
# 202051        5.377423e+07  11201.338784  13866.168738  53.571921  10.007200
# 202052        5.389722e+07   8456.426118  13866.848995  53.571536  10.007791
# 202053        5.304463e+07   7629.139024  13869.494989  53.571694  10.007709
# 202101        5.318415e+07   9796.058974  13870.476923  53.572230  10.008090
# 202102        5.382665e+07  10552.567525  13874.887830  53.572706  10.008642
# 202103        5.290755e+07  10574.097311  13872.097311  53.572160  10.009697
# 202104        5.267806e+07  10575.038107  13876.788822  53.572798  10.008513
# 202105        5.440555e+07  10401.597000  13876.029997  53.573138  10.006962
# 202106        5.565278e+07  10685.601578  13880.259040  53.573454  10.006703
# 202107        5.715392e+07  11159.150411  13882.220033  53.573411  10.006894
# 202108        5.860521e+07  11817.927940  13880.195218  53.573228  10.006524
# 202109        6.006992e+07  11638.334862  13878.360419  53.573252  10.006485
# 202110        6.173058e+07  11602.606341  13875.449141  53.572978  10.006384
# 202111        6.332986e+07  12393.858179  13877.341689  53.572800  10.006216
# 202112        6.477308e+07  11825.509875  13878.011850  53.572628  10.005922
# 202113        6.696785e+07  10956.223910  13875.894320  53.572575  10.005620
# 202114        6.775959e+07  10194.017561  13876.640159  53.572620  10.006823
# 202115        7.131239e+07  11505.838731  13870.878130  53.572872  10.006951
# 202116        7.281500e+07  11541.394833  13873.118251  53.573321  10.007330
# 202117        7.502670e+07  11268.623243  13881.594789  53.573184  10.011614
# 202118        8.313062e+07  11967.131690  13890.915493  53.573434  10.014558
# 202119        9.316002e+07  10671.815966  13892.022607  53.573409  10.014126
# 202120        1.039297e+08  12229.137589  13897.866667  53.574475  10.012538
# 202121        1.148334e+08  12323.006005  13898.156129  53.574457  10.012624
# 202122        1.288787e+08  13333.131056  13903.768560  53.573643  10.007406
# 202123        1.438923e+08  13321.093815  13903.409312  53.573853  10.006211
# 202124        1.505268e+08  12898.859023  13905.186006  53.573733  10.006478
# 202125        1.600247e+08  13006.521340  13908.213051  53.573537  10.005606
# 202126        1.636028e+08  12530.440721  13905.353514  53.572981  10.003421
# 202127        1.730832e+08  12085.585974  13896.971164  53.574083  10.005014
# 202128        1.841673e+08  12013.174643  13896.020000  53.573971  10.005074
# 202129        1.948605e+08  11801.463104  13891.572519  53.573747  10.004346
# 202130        2.046082e+08  12340.513241  13880.793734  53.573775  10.004529
# 202131        2.141725e+08  12948.823352  13876.155179  53.573640  10.005088
# 202132        2.172599e+08  14535.598093  13981.958856  53.575513  10.007827
#
#               Weeknumber
# Week in year
# 202044              44.0
# 202045              45.0
# 202046              46.0
# 202047              47.0
# 202048              48.0
# 202049              49.0
# 202050              50.0
# 202051              51.0
# 202052              52.0
# 202053              53.0
# 202101               1.0
# 202102               2.0
# 202103               3.0
# 202104               4.0
# 202105               5.0
# 202106               6.0
# 202107               7.0
# 202108               8.0
# 202109               9.0
# 202110              10.0
# 202111              11.0
# 202112              12.0
# 202113              13.0
# 202114              14.0
# 202115              15.0
# 202116              16.0
# 202117              17.0
# 202118              18.0
# 202119              19.0
# 202120              20.0
# 202121              21.0
# 202122              22.0
# 202123              23.0
# 202124              24.0
# 202125              25.0
# 202126              26.0
# 202127              27.0
# 202128              28.0
# 202129              29.0
# 202130              30.0
# 202131              31.0
# 202132              32.0

# %%
df_clean_data_weekmean.reset_index(level=0, inplace=True)

# %%
sns.catplot(x="Week in year", y="result", data=df_clean_data_weekmean, height=15, aspect=5, kind = "bar")

# %%
df_clean_data_weekmean.nsmallest(10, 'result')
# Out:
#     Week in year       @iot.id        result            id        lat  \
# 0         202044  5.187067e+07   7514.288136  13850.702179  53.572252
# 9         202053  5.304463e+07   7629.139024  13869.494989  53.571694
# 8         202052  5.389722e+07   8456.426118  13866.848995  53.571536
# 10        202101  5.318415e+07   9796.058974  13870.476923  53.572230
# 23        202114  6.775959e+07  10194.017561  13876.640159  53.572620
# 14        202105  5.440555e+07  10401.597000  13876.029997  53.573138
# 11        202102  5.382665e+07  10552.567525  13874.887830  53.572706
# 12        202103  5.290755e+07  10574.097311  13872.097311  53.572160
# 13        202104  5.267806e+07  10575.038107  13876.788822  53.572798
# 28        202119  9.316002e+07  10671.815966  13892.022607  53.573409
#
#          long  Weeknumber
# 0   10.008534        44.0
# 9   10.007709        53.0
# 8   10.007791        52.0
# 10  10.008090         1.0
# 23  10.006823        14.0
# 14  10.006962         5.0
# 11  10.008642         2.0
# 12  10.009697         3.0
# 13  10.008513         4.0
# 28  10.014126        19.0

# %%
#Explanation lowest traffic weeks
# 2020-44 - (26.10.-1.11.)All saint´s day, Halloween
# 2020-53 - Christmas
# 2020-52 - Christmas
# 2021-01 - New year
# 2021-14 - (05.04. - 11.04.) Easter week
#....
